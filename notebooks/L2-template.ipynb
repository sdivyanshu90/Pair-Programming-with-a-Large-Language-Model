# %% [markdown]
# # Lesson 2: Using a String Template

# %% [markdown]
# #### Setup
# Set the ~~MakerSuite~~ Gemini API key with the provided helper function.

# %%
from utils import get_api_key

# PaLM legacy
## import google.generativeai as palm
## palm.configure(api_key=get_api_key())

# Gemini API
import os
import google.generativeai as genai
from google.api_core import client_options as client_options_lib

genai.configure(
    api_key=get_api_key(),
    transport="rest",
    client_options=client_options_lib.ClientOptions(
        api_endpoint=os.getenv("GOOGLE_API_BASE"),
    )
)

# %% [markdown]
# #### Pick the model that generates text

# %% [markdown]
# ```Python
# # Legacy models shown in the video
# models = [m for m in genai.list_models() if 'generateText' in m.supported_generation_methods]
# model_bison = models[0]
# # Model Bison set as legacy model in 2024
# model_bison
# ```

# %%
# Set the model to connect to the Gemini API
model_flash = genai.GenerativeModel(model_name='gemini-2.0-flash')

# %% [markdown]
# > Note: if you want to learn more about the different Gemini models, check the Short Course [Large Multimodal Model Prompting with Gemini](https://www.deeplearning.ai/short-courses/large-multimodal-model-prompting-with-gemini/)

# %% [markdown]
# ### Legacy PaLM API
# #### Helper function to call the PaLM API
# ```Python
# from google.api_core import retry
# @retry.Retry()
# def generate_text(prompt,
#                   model=model_bison,
#                   temperature=0.0):
#     return palm.generate_text(prompt=prompt,
#                               model=model,
#                               temperature=temperature)
# ```

# %% [markdown]
# ### Helper function to call the Gemini API

# %%
def generate_text(prompt,
                  model=model_flash,
                  temperature=0.0):
    return model_flash.generate_content(prompt,
                                  generation_config={'temperature':temperature})

# %% [markdown]
# #### Prompt template
#
# 1. priming: getting the LLM ready for the type of task you'll ask it to do.
# 2. question: the specific task.
# 3. decorator: how to provide or format the output.

# %%
prompt_template = """
{priming}

{question}

{decorator}

Your solution:
"""

# %%
priming_text = "You are an expert at writing clear, concise, Python code."

# %%
question = "create a doubly linked list"

# %% [markdown]
# #### Observe how the decorator affects the output
# - In other non-coding prompt engineering tasks, it's common to use "chain-of-thought prompting" by asking the model to work through the task "step by step".
# - For certain tasks like generating code, you may want to experiment with other wording that would make sense if you were asking a developer the same question.
#
# In the code cell below, try out option 1 first, then try out option 2.

# %%
# option 1
# decorator = "Work through it step by step, and show your work. One step per line."

# option 2
decorator = "Insert comments for each line of code."

# %%
prompt = prompt_template.format(priming=priming_text,
                                question=question,
                                decorator=decorator)

# %% [markdown]
# #### review the prompt

# %%
print(prompt)
# Out:
# You are an expert at writing clear, concise, Python code.
#
# create a doubly linked list
#
# Insert comments for each line of code.
#
# Your solution:

# %% [markdown]
# #### Call the API to get the completion

# %%
completion = generate_text(prompt)
# Gemini API
print(completion.text)

# PaLM legacy
## print(completion.result)
# Out:
# ```python
# class Node:
#     """
#     Represents a node in a doubly linked list.
#     """
#     def __init__(self, data):
#         """
#         Initializes a new node with the given data.
#         """
#         self.data = data  # Store the data in the node
#         self.next = None  # Pointer to the next node, initially None
#         self.prev = None  # Pointer to the previous node, initially None
#
#
# class DoublyLinkedList:
#     """
#     Represents a doubly linked list.
#     """
#     def __init__(self):
#         """
#         Initializes an empty doubly linked list.
#         """
#         self.head = None  # Head of the list, initially None
#         self.tail = None  # Tail of the list, initially None
#
#     def append(self, data):
#         """
#         Appends a new node with the given data to the end of the list.
#         """
#         new_node = Node(data)  # Create a new node with the given data
#
#         if self.head is None:  # If the list is empty
#             self.head = new_node  # The new node becomes the head
#             self.tail = new_node  # The new node also becomes the tail
#         else:
#             self.tail.next = new_node  # The current tail's next points to the new node
#             new_node.prev = self.tail  # The new node's previous points to the current tail
#             self.tail = new_node  # The new node becomes the new tail
#
#     def prepend(self, data):
#         """
#         Prepends a new node with the given data to the beginning of the list.
#         """
#         new_node = Node(data)  # Create a new node with the given data
#
#         if self.head is None:  # If the list is empty
#             self.head = new_node  # The new node becomes the head
#             self.tail = new_node  # The new node also becomes the tail
#         else:
#             new_node.next = self.head  # The new node's next points to the current head
#             self.head.prev = new_node  # The current head's previous points to the new node
#             self.head = new_node  # The new node becomes the new head
#
#     def insert_after(self, prev_node, data):
#         """
#         Inserts a new node with the given data after the specified node.
#         """
#         if prev_node is None:  # If the previous node is None
#             print("Previous node cannot be None")  # Print an error message
#             return
#
#         new_node = Node(data)  # Create a new node with the given data
#         new_node.next = prev_node.next  # The new node's next points to the previous node's next
#         prev_node.next = new_node  # The previous node's next points to the new node
#         new_node.prev = prev_node  # The new node's previous points to the previous node
#
#         if new_node.next is not None:  # If the new node is not the last node
#             new_node.next.prev = new_node  # The node after the new node's previous points to the new node
#
#         if prev_node == self.tail:
#             self.tail = new_node
#
#     def delete_node(self, node):
#         """
#         Deletes the specified node from the list.
#         """
#         if self.head is None or node is None:  # If the list is empty or the node is None
#             return  # Do nothing
#
#         if node == self.head:  # If the node to be deleted is the head
#             self.head = node.next  # Update the head to the next node
#
#         if node == self.tail:
#             self.tail = node.prev
#
#         if node.next is not None:  # If the node to be deleted is not the last node
#             node.next.prev = node.prev  # Update the next node's previous pointer
#
#         if node.prev is not None:  # If the node to be deleted is not the first node
#             node.prev.next = node.next  # Update the previous node's next pointer
#
#     def print_list(self):
#         """
#         Prints the data in the list from head to tail.
#         """
#         node = self.head  # Start from the head
#         while node:  # While there are nodes in the list
#             print(node.data, end=" ")  # Print the data of the current node
#             node = node.next  # Move to the next node
#         print()  # Print a newline character
#
#     def print_list_reverse(self):
#         """
#         Prints the data in the list from tail to head.
#         """
#         node = self.tail  # Start from the tail
#         while node:  # While there are nodes in the list
#             print(node.data, end=" ")  # Print the data of the current node
#             node = node.prev  # Move to the previous node
#         print()  # Print a newline character
#
#
# # Example usage:
# if __name__ == '__main__':
#     dll = DoublyLinkedList()  # Create a new doubly linked list
#     dll.append(1)  # Append 1 to the list
#     dll.append(2)  # Append 2 to the list
#     dll.append(3)  # Append 3 to the list
#
#     print("Doubly Linked List:")
#     dll.print_list()  # Print the list: 1 2 3
#
#     print("Doubly Linked List in reverse:")
#     dll.print_list_reverse() # Print the list in reverse: 3 2 1
#
#     dll.prepend(0)  # Prepend 0 to the list
#     print("Doubly Linked List after prepending 0:")
#     dll.print_list()  # Print the list: 0 1 2 3
#
#     node_to_insert_after = dll.head.next  # Get the second node (1)
#     dll.insert_after(node_to_insert_after, 1.5)  # Insert 1.5 after the second node
#     print("Doubly Linked List after inserting 1.5 after 1:")
#     dll.print_list()  # Print the list: 0 1 1.5 2 3
#
#     node_to_delete = dll.head.next.next  # Get the third node (1.5)
#     dll.delete_node(node_to_delete)  # Delete the third node
#     print("Doubly Linked List after deleting 1.5:")
#     dll.print_list()  # Print the list: 0 1 2 3
#
#     dll.delete_node(dll.head)
#     print("Doubly Linked List after deleting head (0):")
#     dll.print_list() # Print the list: 1 2 3
#
#     dll.delete_node(dll.tail)
#     print("Doubly Linked List after deleting tail (3):")
#     dll.print_list() # Print the list: 1 2
# ```

# %% [markdown]
# #### Try another question

# %%
question = """create a very large list of random numbers in python, 
and then write code to sort that list"""

# %%
prompt = prompt_template.format(priming=priming_text,
                                question=question,
                                decorator=decorator)

# %%
print(prompt)
# Out:
# You are an expert at writing clear, concise, Python code.
#
# create a very large list of random numbers in python,
# and then write code to sort that list
#
# Insert comments for each line of code.
#
# Your solution:

# %%
completion = generate_text(prompt)
print(completion.text)
# Out:
# ```python
# import random  # Import the random module for generating random numbers
# import time  # Import the time module for measuring execution time
#
# def sort_large_list(size):
#     """
#     Generates a large list of random numbers and sorts it using Python's built-in sort function.
#
#     Args:
#         size (int): The number of random integers to generate in the list.
#
#     Returns:
#         list: The sorted list of random numbers.  Also prints the time taken to sort.
#     """
#
#     # Generate a list of random integers
#     random_list = [random.randint(0, 1000000) for _ in range(size)]  # Create a list of 'size' random integers between 0 and 1,000,000
#
#     # Record the start time
#     start_time = time.time()  # Get the current time before sorting
#
#     # Sort the list using the built-in sort method (Timsort algorithm)
#     random_list.sort()  # Sort the list in place (modifies the original list)
#
#     # Record the end time
#     end_time = time.time()  # Get the current time after sorting
#
#     # Calculate the elapsed time
#     elapsed_time = end_time - start_time  # Calculate the time taken for sorting
#
#     print(f"Sorting {size} elements took {elapsed_time:.4f} seconds")  # Print the time taken
#
#     return random_list  # Return the sorted list
#
#
# if __name__ == "__main__":
#     list_size = 1000000  # Define the size of the list (e.g., 1 million)
#     sorted_list = sort_large_list(list_size)  # Generate and sort the list
#     # Optionally, you can print the first few elements to verify the sorting
#     # print(sorted_list[:10]) # Print the first 10 elements of the sorted list
# ```

# %% [markdown]
# #### Try out the generated code
# - Debug it as needed.  For instance, you may need to import `random` in order to use the `random.randint()` function.

# %%
import random


# copy-paste some of the generated code that generates random numbers
random_numbers = [random.randint(0, 100) for _ in range(100000)]
print(random_numbers)
# Out:
# [50, 57, 77, 60, 69, 55, 8, 72, 60, 48, 34, 61, 30, 61, 12, 31, 70, 43, 67, 24, 83, 31, 62, 43, 12, 51, 96, 81, 16, 4, 28, 89, 43, 7, 45, 88, 87, 65, 19, 61, 82, 85, 87, 15, 45, 14, 84, 18, 97, 8, 59, 55, 15, 97, 50, 1, 59, 32, 54, 53, 31, 9, 8, 23, 69, 30, 68, 30, 45, 51, 15, 34, 30, 82, 15, 11, 56, 54, 98, 96, 44, 86, 18, 20, 64, 100, 32, 48, 13, 29, 18, 83, 90, 24, 46, 88, 49, 42, 83, 17, 91, 43, 19, 27, 56, 9, 20, 41, 3, 83, 83, 63, 45, 94, 92, 49, 33, 77, 25, 49, 26, 14, 30, 5, 51, 83, 7, 1, 0, 47, 99, 48, 1, 38, 77, 81, 68, 30, 26, 2, 70, 62, 88, 67, 100, 31, 4, 17, 12, 52, 72, 17, 54, 12, 45, 17, 44, 23, 86, 41, 39, 90, 32, 74, 31, 41, 23, 83, 84, 56, 20, 89, 2, 77, 21, 15, 47, 21, 46, 34, 54, 14, 74, 29, 27, 19, 93, 30, 0, 16, 23, 48, 81, 85, 41, 99, 41, 21, 62, 8, 62, 19, 3, 0, 39, 89, 65, 44, 29, 51, 62, 73, 22, 72, 26, 57, 35, 54, 2, 82, 93, 25, 70, 42, 96, 2, 91, 74, 74, 60, 100, 96, 42, 38, 12, 17, 13, 80, 68, 28, 73, 73, 58, 53, 25, 72, 19, 57, 59, 35, 67, 39, 3, 51, 44, 74, 77, 55, 71, 2, 13, 42, 16, 13, 82, 67, 52, 5, 90, 17, 90, 58, 0, 70, 69, 93, 67, 27, 89, 76, 80, 67, 1, 91, 95, 61, 64, 7, 2, 25, 56, 9, 94, 50, 94, 80, 2, 25, 39, 78, 24, 80, 37, 57, 56, 80, 93, 36, 92, 98, 61, 20, 73, 31, 21, 17, 40, 57, 88, 39, 21, 69, 26, 84, 58, 42, 37, 55, 83, 30, 86, 30, 68, 66, 58, 82, 31, 89, 17, 5, 57, 29, 64, 25, 57, 39, 50, 93, 24, 90, 67, 25, 28, 61, 10, 71, 93, 79, 87, 8, 44, 77, 70, 62, 83, 78, 30, 48, 68, 78, 70, 2, 91, 6, 28, 63, 1, 21, 19, 10, 11, 39, 35, 74, 96, 4, 86, 52, 40, 9, 97, 21, 77, 96, 7, 14, 64, 77, 7, 45, 56, 47, 81, 31, 61, 32, 96, 15, 56, 55, 97, 22, 79, 43, 84, 75, 76, 78, 32, 75, 7, 87, 35, 22, 57, 51, 28, 81, 86, 68, 94, 24, 68, 85, 90, 80, 88, 53, 55, 97, 66, 54, 31, 5, 77, 50, 47, 26, 80, 63, 18, 42, 65, 37, 7, 12, 45, 84, 53, 16, 93, 64, 46, 7, 46, 3, 20, 70, 64, 79, 85, 79, 56, 20, 34, 86, 15, 19, 22, 64, 23, 10, 66, 2, 17, 57, 74, 84, 7, 21, 9, 7, 46, 96, 26, 17, 63, 48, 66, 44, 94, 61, 78, 31, 49, 44, 88, 62, 63, 39, 27, 65, 99, 75, 30, 60, 8, 67, 65, 48, 87, 5, 46, 82, 53, 37, 45, 39, 35, 38, 93, 88, 37, 13, 75, 78, 21, 91, 6, 78, 54, 64, 14, 93, 29, 59, 21, 98, 0, 31, 49, 46, 52, 5, 49, 66, 22, 83, 3, 93, 85, 78, 17, 52, 52, 43, 62, 100, 40, 86, 25, 80, 70, 46, 2, 89, 59, 37, 13, 2, 69, 7, 92, 80, 33, 32, 65, 57, 61, 98, 6, 81, 90, 65, 56, 12, 12, 15, 26, 74, 6, 5, 92, 25, 84, 86, 38, 84, 52, 66, 84, 26, 16, 12, 39, 26, 51, 56, 31, 58, 10, 87, 41, 32, 60, 34, 37, 95, 51, 2, 90, 0, 71, 59, 77, 71, 26, 60, 66, 8, 77, 70, 6, 95, 24, 61, 7, 100, 100, 40, 4, 28, 60, 33, 41, 2, 27, 94, 82, 68, 11, 2, 50, 20, 57, 14, 97, 39, 50, 20, 73, 20, 61, 47, 19, 88, 21, 17, 5, 71, 5, 41, 24, 79, 0, 43, 24, 78, 75, 33, 7, 39, 7, 73, 70, 21, 92, 74, 91, 59, 20, 76, 75, 13, 92, 51, 45, 27, 67, 22, 17, 6, 94, 80, 79, 20, 75, 90, 91, 10, 40, 72, 80, 74, 44, 2, 52, 20, 91, 37, 12, 87, 4, 51, 30, 19, 23, 57, 73, 31, 84, 87, 4, 22, 60, 45, 5, 91, 25, 100, 40, 74, 34, 24, 20, 27, 85, 88, 7, 87, 94, 37, 60, 20, 22, 58, 7, 68, 11, 43, 27, 40, 28, 82, 10, 97, 39, 52, 50, 83, 95, 21, 33, 21, 5, 98, 46, 10, 67, 60, 97, 26, 81, 14, 72, 97, 84, 11, 36, 30, 58, 53, 30, 22, 64, 41, 64, 51, 66, 71, 52, 39, 99, 10, 16, 25, 22, 4, 35, 77, 97, 17, 21, 59, 14, 50, 50, 22, 62, 84, 45, 89, 71, 2, 17, 41, 53, 7, 89, 70, 17, 16, 53, 92, 5, 25, 32, 1, 79, 81, 38, 15, 61, 69, 2, 68, 54, 5, 70, 74, 7, 45, 40, 83, 98, 48, 35, 75, 25, 37, 36, 76, 66, 39, 78, 55, 91, 100, 89, 29, 43, 97, 11, 63, 83, 70, 94, 32, 69, 86, 13, 72, 29, 56, 60, 46, 10, 13, 58, 70, 86, 4, 88, 84, 37, 12, 35, 28, 35, 18, 6, 99, 64, 91, 78, 42, 82, 24, 68, 87, 43, 32, 17, 33, 3, 96, 3, 56, 51, 1, 69, 5, 46, 63, 30, 67, 48, 86, 42, 28, 83, 13, 81, 98, 39, 8, 23, 44, 94, 53, 79, 48, 24, 27, 66, 81, 88, 47, 13, 100, 33, 42, 35, 54, 32, 63, 68, 7, 55, 50, 80, 98, 80, 79, 60, 100, 21, 94, 39, 16, 47, 55, 36, 60, 96, 42, 73, 50, 17, 46, 2, 26, 22, 34, 13, 76, 24, 35, 88, 77, 6, 53, 2, 43, 90, 6, 16, 33, 21, 25, 72, 31, 12, 33, 44, 53, 7, 21, 56, 28, 44, 90, 96, 8 ...
